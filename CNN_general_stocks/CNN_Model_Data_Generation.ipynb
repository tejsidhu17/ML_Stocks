# %%
import CNN_general_stocks
import numpy as np
import pandas as pd
import yfinance as yf
import pandas as pd
import numpy as np
from collections import Counter
import warnings

warnings.filterwarnings("ignore")

defense_materials_tickers = ["GD", "HII", "AA", "KTOS", "X", "RTX", "NOC", "LMT", "FCX", "MT", "NEM", "BHP", "TER", "CF",
           "CLF", "CACI", "VALE", "HCC", "LHX", "CVX", "XOM", "MPC", "PSX", "COP", "SHEL", "BP", "DVN", "ET", "SM", "CNX", "SLB",
           "OXY", "HAL", "ALB", "SQM", "LAC", "MP", "CNR", "ATI", "CDE", "TECK", "GOLD", "CMC", "TMC", "BA", "LDOS",
           "CCJ", "EU", "CLMT", "BWXT", "UUUU", "UEC", "YPF", "KMI", "EPD", "EC", "AMCR", "CVI", "INSW", "SBLK", "DOW", "LYB",
           "HWM", "TXT", "AXON", "TDG", "CAT", "DE", "PCAR", "UNP", "CSX", "NSC", "WAB", "HON", "MMM", "WMB", "OKE", "TRGP",
           "VLO", "BKR", "EOG", "HES", "FANG", "TPL", "EXE", "CTRA", "APA", "EQT", "CEG", "VST", "NRG", "OKLO", "SRE", "AES",
           "ATO", "NI", "AWK", "LIN", "SHW", "APD", "DD", "PPG", "IFF", "EMN", "CTVA", "MOS", "VMC", "MLM", "NUE", "STLD",
           "XEL", "NEE", "SO", "DUK", "AEP", "EXC", "PEG", "ED", "PCG", "ETR", "WEC", "DTE", "AEE", "PPL", "CNP",
           "FE", "ES", "EIX", "CMS", "LNT", "EVRG", "PNW", "TTE", "RGP", "D", "DNN", "NXE", "URG", "UROY", "LEU", "SMR", "AG",
           "HL", "EXK", "PAAS", "SAND", "PBR", "RIO", "SCCO", "BBD"]

banks_financial_institutions = ["JPM", "C", "MUFG", "DB", "UBS", "WFC", "BAC", "GS", "MS", "V", "BCS", "USB", "TROW", "SYF",
                                "COF", 'MSCI', "BLK", "BX", "AXP", "MA", "IBKR", "SCHW", "BK", "ICE", "NDAQ", "CME",
                                "MAIN", "PRU", "TFC", "HSBC", "PNC", "MFG", "RF", "SLM", "KKR", "APO", "AMP", "RJF",
                                "AMT", "EQIX", "DLR", "CCI", "IRM", "SBAC", "WY", "AVB", "PLD", "PSA", "EXR", "O",
                                "SPG", "KIM", "REG", "FRT", "CBRE", "CSGP", "EQR", "INVH", "ESS", "MAA", "UDR", "CPT",
                                "WELL", "VTR", "DOC", "ARE", "HST", "WPC", "AGNC", "LTC", "PSEC", "NLY", "OCSL", "OHI",
                                "BXP", "SLG", "MKTX", "AIG", "ACGL", "STT", "NTRS", "PFG", "IVZ", "PGR", "CB", "TRV", "ALL", 
                                "HIG", "WRB", "CINF", "L", "AIZ", "SPGI", "MCO", "CBOE", "FDS", "MMC", "AJG", "AON", "BRO",
                                "WTW", "ERIE", "AFL", "MET", "GL", "MTB", "FITB", "HBAN", "CFG", "KEY", "EG", "LYG", "FLG",
                                "BMA", "GGAL", "ITUB"]

telecom_airlines_rest = ["TMUS", "VZ", "T", "MO", "PM", "DAL", "UAL", "LUV", "AAL", "ALK", "JBLU", "WMT", "COST", "HAS", "W",
                         "WSM", "VICI", "PARA", "LEN", "GAP", "GEV", "GE", "HD", "LOW", "TGT", "LULU", "ROST", "NKE", "DLTR",
                         "SIG", "DG", "CVNA", "GO", "OLLI", "ULTA", "SFM", "ORLY", "AZO", "SKYW", "ALGT", "TJX", "MCK", "CVS",
                         "LQDT", "HIMS", "EBAY", "CHWY", "CPRT", "BIGC", "EXPE", "BKNG", "MMYT", "DIS", "EA", "CMCSA", "TTWO",
                         "F", "GM", "TSLA", "RIVN", "LCID", "MCD", "CMG", "SBUX", "YUM", "DRI", "DPZ", "TSCO", "BBY", "NCLH",
                         "RCL", "CCL", "DECK", "IP", "SWK", "SW", "BALL", "AVY", "PKG", "LKQ", "APTV", "GPC", "LVS", "WYNN",
                         "MGM", "CZR", "DHI", "NVR", "PHM", "TPR", "RL", "MHK", "ROL", "PG", "CL", "KMB", "CHD", "CLX", "EL", "KVUE",
                         "KO", "PEP", "MNST", "KDP", "CELH", "KHC", "GIS", "K", "MKC", "HRL", "CAG", "SJM", "CPB", "MDLZ", "HSY",
                         "ADM", "TSN", "BG", "KR", "STZ", "TAP", "SYY", "WM", "RSG", "UPS", "FDX", "EXPD", "JBHT", "CHRW", "CTAS",
                         "VRSK", "EFX", "ODFL", "SNA", "HUBB", "ALLE", "VLTO", "URI", "GWW", "FAST", "POOL", "TT", "CARR", "JCI", "LII",
                         "MAS", "BLDR", "ETN", "PH", "ITW", "EMR", "CMI", "OTIS", "AME", "IR", "ROK", "XYL", "DOV", "PNR", "IEX",
                         "NDSN", "AOS", "GNRC", "CHTR", "MTCH", "LYV", "WBD", "TKO", "FOXA", "NWS", "PWR", "J", "ECL", "TMDX", "ULCC",
                         "USAC", "STLA", "XRX", "STR", "WHR", "TM", "HMC", "LW", "GME", "WOOF", "GRWG", "FIVE", "RH", "DKS", "BMY",
                         "SERV", "PTLO", "SHAK", "TXRH", "DNUT", "YUMC", "CBRL", "TWNP", "BLMN", "CAVA", "ARMK", "BROS", "PBPB", "DENN",
                         "RRGB", "PZZA", "XXII", "SFIX", "LIVE", "ONON", "SKX", "CROX", "IRBT", "GOOS", "TRNR", "POWW", "MODG",
                         "VMAR", "ATER", "SWBI", "FOSL", "KBSX", "VRA", "CPRI", "VNCE", "HBI", "VFC", "OXM", "UAA", "CRI", "ZGN", "AS",
                         "DOGZ", "JRSH", "LEVI", "HLT", "GBTG", "TNL", "VCSA", "SHCO", "PLYA", "HTHT", "TCOM", "CHH",
                         "MAR", "YTRA", "SABR", "VIK"]

tech = ["TXN", "INTC", "QCOM", "AMD", "NVDA", "AMAT", "TSM", "MU", "AVGO", "ON", "ADI", "GFS", "ASML", "SMCI", "DELL", "HPE", "HPQ", "SNPS",
        "ACLS", "MRVL", "KLAC", "LRCX", "FOUR", "IBTA", "CTLP", "LIF", "ONTO", "SYM", "YMM", "CAMT", "XYZ", "PAYC", "JD", "BABA", "TWLO",
        "PYPL", "CHPT", "KVYO", "APP", "SEDG", "PLUG", "PONY", "WOLF", "NIO", "PERI", "FTNT", "SNOW", "ZS", "GOOGL", "ANET", "NFLX",
        "MSFT", "META", "IBM", "ORCL", "AMZN", "AAPL", "SONY", "DXC", "COHR", "PCOR", "LI", "BILI", "BIDU", "PDD", "JFIN", "PANW",
        "CRWD", "OKTA", "DDOG", "NET", "OPRA", "FN", "SOFI", "NU", "EPAM", "LYFT", "TEAM", "SPOT", "DKNG", "ABNB", "SONO", "UBER", "UPST",
        "AI", "A", "CHKP", "CYBR", "GEN", "PLTR", "GDDY", "CPAY", "GPN", "VRSN", "FFIV", "DASH", "FSLR", "ENPH", "AFRM",
        "APH", "TEL", "GLW", "JBL", "GRMN", "KEYS", "FTV", "TDY", "TRMB", "NTAP", "STX", "WDC", "CSCO", "MSI", "ZBRA", "JNPR", "ACN",
        "FI", "FIS", "CTSH", "IT", "BR", "CDW", "JKHY", "CRM", "NOW", "WDAY", "INTU", "ADBE", "ADP", "CDNS", "ROP", "ADSK", "PAYX", "FICO",
        "ANSS", "TYL", "PTC", "DAY", "NXPI", "MPWR", "MCHP", "SWKS", "ISRG", "NTNX", "PSTG", "AKAM", "INFY", "QBTS", "NOK", "BB", "HOOD",
        "MSTR", "COIN", "CLSk", "EVGO", "RBLX", "SOUN", "MARA", "ARM", "ALAB", "MDB", "GTLB", "PATH", "SHOP", "ZM", "ROKU", "TTD", "DOCU",
        "PINS", "ETSY", "TDOC", "FSLY", "FVRR", "SNAP", "PTON", "LMND", "AYI", "NXT", "FCEL", "BLDP", "BLNK", "QS", "XPEV", "WKHS", "BE",
        "SPCE", "LSCC", "LAZR"]

bio = ["AVXL", "GILD", "VRTX", "ALT", "GPCR", "RLAY", "GSK", "ABBV", "PFE", "RHHBY", "VKTX", "RXRX", "LLY", "NVO", "SNY", "MRK", "JNJ", "AMGN",
       "AZN", "ABT", "UNH", "MRNA", "BNTX", "NVAX", "SMMT", "CRSP", "NTLA", "REGN", "TNXP", "ANVS", "SAVA", "AXSM", "IOVA", "CGTX",
       "ANNX", "ACIU", "INMB", "MIST", "AUPH", "ARDX", "TGTX", "BCRX", "DVAX", "MCRB", "BIIB", "VIR", "ARCT", "ABUS", "HUM", "ELV",
       "CI", "CNC", "MOH", "OSCR", "CLOV", "ALHC", "PGNY", "TMO", "DHR", "IDXX", "IQV", "MTD", "WAT", "LH", "DGX", "RVTY", "CRL", "BDX",
       "RMD", "BAX", "WST", "COO", "HOLX", "ALGN", "INCY", "TECH", "ZTS", "VTRS", "SOLV", "WBA", "HCA", "DVA", "UHS", "COR", "CAH", "HSIC",
       "BSX", "SYK", "MDT", "EW", "GEHC", "DXCM", "ZBH", "STE", "PODD", "OMI", "PDCO", "ZYXI", "COSM", "AHG", "FMS", "THC", "EHC", "ACHC",
       "CHE", "AMED", "PACS", "ENSG", "INO", "ALNY", "INSM", "NBIX", "UTHR", "NTRA", "EXAS", "MDGL", "BMRN", "HALO", "BPMC", "EXEL", "BBIO",
       "SRPT", "CYTK", "RVMD", "IONS", "ROIV", "PCVX", "ALKS", "SWTX"]

tickers = defense_materials_tickers + banks_financial_institutions + telecom_airlines_rest + tech + bio

print(len(defense_materials_tickers))
print(len(banks_financial_institutions))
print(len(telecom_airlines_rest))
print(len(tech))
print(len(bio))
print(len(tickers))
print(Counter(tickers))

data = CNN_general_stocks.get_features(tech)

data["RSI_14"].describe()
data["Max_Drawdown_20"].describe()
# Out:
# 150
# 116
# 248
# 188
# 129
# 831
# ...

# %%
ticker = yf.download("AAPL", period="10y", progress=False)
print(ticker.index)
print(type(ticker.index))
# Out:
# DatetimeIndex(['2015-12-28', '2015-12-29', '2015-12-30', '2015-12-31',
#                '2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11',
#                ...
#                '2025-12-11', '2025-12-12', '2025-12-15', '2025-12-16',
#                '2025-12-17', '2025-12-18', '2025-12-19', '2025-12-22',
#                '2025-12-23', '2025-12-24'],
#               dtype='datetime64[ns]', name='Date', length=2514, freq=None)
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data = CNN_general_stocks.get_features_LSTM(tickers)

sequence_length = 60
X_train = []
y_train = []

X_val = []
y_val = []

X_test = []
y_test = []
for d in data:
     features = d.copy()
     features = features.drop(columns=["Next_Day_Return"])

     train_num = (len(d) - sequence_length) * 0.6
     val_num = (len(d) - sequence_length) * 0.2
     test_num = (len(d) - sequence_length) * 0.2
     for i in range(len(d) - sequence_length):
          X_window = features.iloc[i : i + sequence_length].values

          day_return = (d.iloc[i + sequence_length]["Next_Day_Return"])
          
          if(i < train_num):
               X_train.append(X_window)
               y_train.append(day_return)
          elif (i < train_num + val_num):
               X_val.append(X_window)
               y_val.append(day_return)
          else:
               X_test.append(X_window)
               y_test.append(day_return)


X_train = np.array(X_train)
y_train = np.array(y_train)

X_val = np.array(X_val)
y_val = np.array(y_val)

X_test = np.array(X_test)
y_test = np.array(y_test)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# Ticker: GD
# Ticker: HII
# Ticker: AA
# Ticker: KTOS
# Ticker: X
# 1 Failed download:
# ['X']: YFPricesMissingError('possibly delisted; no price data found  (period=10y) (Yahoo error = "No data found, symbol may be delisted")')
# Ticker: RTX
# Ticker: NOC
# Ticker: LMT
# Ticker: FCX
# Ticker: MT
# Ticker: NEM
# Ticker: BHP
# Ticker: TER
# Ticker: CF
# Ticker: CLF
# Ticker: CACI
# Ticker: VALE
# Ticker: HCC
# Ticker: LHX
# Ticker: CVX
# Ticker: XOM
# Ticker: MPC
# Ticker: PSX
# Ticker: COP
# Ticker: SHEL
# Ticker: BP
# Ticker: DVN
# Ticker: ET
# Ticker: SM
# Ticker: CNX
# Ticker: SLB
# Ticker: OXY
# Ticker: HAL
# Ticker: ALB
# Ticker: SQM
# Ticker: LAC
# Ticker: MP
# Ticker: CNR
# Ticker: ATI
# Ticker: CDE
# Ticker: TECK
# Ticker: GOLD
# Ticker: CMC
# Ticker: TMC
# Ticker: BA
# Ticker: LDOS
# Ticker: CCJ
# Ticker: EU
# Ticker: CLMT
# Ticker: BWXT
# Ticker: UUUU
# Ticker: UEC
# Ticker: YPF
# Ticker: KMI
# Ticker: EPD
# Ticker: EC
# Ticker: AMCR
# Ticker: CVI
# Ticker: INSW
# ...

# %%
np.save("LSTM_Data/X_train.npy", X_train)
np.save("LSTM_Data/y_train.npy", y_train)

np.save("LSTM_Data/X_test.npy", X_test)
np.save("LSTM_Data/y_test.npy", y_test)

np.save("LSTM_Data/X_val.npy", X_val)
np.save("LSTM_Data/y_val.npy", y_val)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
